# %%
import pandas as pd
import numpy as np
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\webfr\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
GCE = pd.read_csv(r"C:\Users\webfr\Desktop\DataScienceProject\GuilfordCounty_emotion_data.csv")
GCE.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
top_freq_num = 4
a = GCE['word'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Word', 'Frequency'])
print(freq_result)
# Out:
#       Word  Frequency
# 0   County        353
# 1   Public        330
# 2  General        288
# 3   Budget        274

# %%
CCE = pd.read_csv(r"C:\Users\webfr\Desktop\DataScienceProject\CharlotteCity_emotion_data.csv")
CCE.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
top_freq_num = 10
a = CCE['word'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Word', 'Frequency'])
print(freq_result)
# Out:
#          Word  Frequency
# 0    Planning        468
# 1     Council        420
# 2         Pay        344
# 3  Retirement        336
# 4     General        318
# 5      Public        304
# 6     Provide        284
# 7      Budget        251
# 8     Improve        232
# 9         Art        205

# %%
RCE = pd.read_csv(r"C:\Users\webfr\Desktop\DataScienceProject\RaleighCity_emotion_data.csv")
RCE.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
top_freq_num = 4
a = RCE['word'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Word', 'Frequency'])
print(freq_result)
# Out:
#         Word  Frequency
# 0  Resources        288
# 1    Council        225
# 2     Public        220
# 3    General        216

# %%
DCE = pd.read_csv(r"C:\Users\webfr\Desktop\DataScienceProject\DurhamCity_emotion_data.csv")
DCE.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
top_freq_num = 4
a = DCE['word'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Word', 'Frequency'])
print(freq_result)
# Out:
#        Word  Frequency
# 0    Public        268
# 1   General        262
# 2    Income        258
# 3  Planning        249

# %%
DCNTE = pd.read_csv(r"C:\Users\webfr\Desktop\DataScienceProject\DurhamCounty_emotion_data.csv")
DCNTE.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
top_freq_num = 4
a = DCNTE['word'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Word', 'Frequency'])
print(freq_result)
# Out:
#      Word  Frequency
# 0   Youth        264
# 1  Public        252
# 2  Income        252
# 3  County        240

# %%
MCE = pd.read_csv(r"C:\Users\webfr\Desktop\DataScienceProject\MecklenburgCounty_emotion_data.csv")
MCE.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
top_freq_num = 4
a = MCE['word'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Word', 'Frequency'])
print(freq_result)
# Out:
#      Word  Frequency
# 0  Budget        529
# 1  County        529
# 2   Count        510
# 3  Rating        416

# %%
WCE = pd.read_csv(r"C:\Users\webfr\Desktop\DataScienceProject\WakeCounty_emotion_data.csv")
WCE.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
top_freq_num = 4
a = WCE['word'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Word', 'Frequency'])
print(freq_result)
# Out:
#       Word  Frequency
# 0   Budget        497
# 1   Public        450
# 2  General        408
# 3   County        378

# %%
top_freq_num = 10
a = WCE['sentiment'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result1 = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Sentiment', 'WakeCounty'])
print(freq_result1)
# Out:
#       Sentiment  WakeCounty
# 0      Positive        7318
# 1         Trust        5058
# 2  Anticipation        2547
# 3      Negative        1932
# 4           Joy        1412
# 5          Fear        1058
# 6       Sadness         799
# 7         Anger         498
# 8      Surprise         436
# 9       Disgust         331

# %%
top_freq_num = 10
a = MCE['sentiment'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result2 = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Sentiment', 'MecklenburgCounty'])
print(freq_result2)
# Out:
#       Sentiment  MecklenburgCounty
# 0      Positive               4912
# 1         Trust               4134
# 2      Negative               1540
# 3  Anticipation               1539
# 4          Fear               1030
# 5           Joy                893
# 6       Sadness                631
# 7         Anger                502
# 8      Surprise                255
# 9       Disgust                224

# %%
top_freq_num = 10
a = DCNTE['sentiment'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result3 = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Sentiment', 'DurhamCity'])
print(freq_result3)
# Out:
#       Sentiment  DurhamCity
# 0      Positive        5557
# 1         Trust        3696
# 2  Anticipation        1993
# 3      Negative        1546
# 4           Joy        1189
# 5          Fear         930
# 6       Sadness         657
# 7         Anger         480
# 8      Surprise         397
# 9       Disgust         258

# %%
top_freq_num = 10
a = DCE['sentiment'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result4 = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Sentiment', 'Frequency'])
print(freq_result4)
# Out:
#       Sentiment  Frequency
# 0      Positive       5492
# 1         Trust       3394
# 2  Anticipation       1945
# 3      Negative       1312
# 4           Joy       1113
# 5          Fear        714
# 6       Sadness        452
# 7         Anger        384
# 8      Surprise        349
# 9       Disgust        255

# %%
top_freq_num = 10
a = RCE['sentiment'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result5 = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Sentiment', 'RaleighCity'])
print(freq_result5)
# Out:
#       Sentiment  RaleighCity
# 0      Positive         3992
# 1         Trust         2697
# 2  Anticipation         1296
# 3      Negative          905
# 4           Joy          896
# 5          Fear          514
# 6       Sadness          363
# 7         Anger          271
# 8      Surprise          260
# 9       Disgust          216

# %%
top_freq_num = 10
a = CCE['sentiment'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result6 = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Sentiment', 'CharlloteCity'])
print(freq_result6)
# Out:
#       Sentiment  CharlloteCity
# 0      Positive           5994
# 1         Trust           4016
# 2  Anticipation           2303
# 3      Negative           1293
# 4           Joy           1147
# 5          Fear            837
# 6       Sadness            528
# 7         Anger            391
# 8      Surprise            320
# 9       Disgust            181

# %%
top_freq_num = 10
a = GCE['sentiment'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_freq = nltk.FreqDist(words)
freq_result7 = pd.DataFrame(word_freq.most_common(top_freq_num),
                    columns=['Sentiment', 'GilfordCounty'])
print(freq_result7)
freq_result1.plot()
freq_result2.plot()
freq_result3.plot()
freq_result5.plot()
freq_result6.plot()
freq_result7.plot()
# Out:
#       Sentiment  GilfordCounty
# 0      Positive           5729
# 1         Trust           4051
# 2  Anticipation           2043
# 3      Negative           1728
# 4           Joy           1066
# 5          Fear            930
# 6       Sadness            659
# 7         Anger            459
# 8      Surprise            367
# 9       Disgust            306

# %%
ax = freq_result1.plot() 
freq_result2.plot(ax=ax)
freq_result3.plot(ax=ax)
freq_result5.plot(ax=ax)
freq_result6.plot(ax=ax)
freq_result7.plot(ax=ax)
