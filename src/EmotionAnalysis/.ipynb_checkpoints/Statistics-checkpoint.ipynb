# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
GCE = pd.read_csv(r"C:\unnati\datascience\project\Repo\new branch\Budget_Text_Analysis\util\data\structured\emotion\GuilfordCounty_emotion_data.csv")
GCE.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
GCE.describe()
# Out:
#         page_number    sent_count
# count  17338.000000  17338.000000
# mean     217.690852      1.635310
# std      128.187342      1.654592
# min        2.000000      1.000000
# 25%      122.000000      1.000000
# 50%      207.000000      1.000000
# 75%      304.000000      2.000000
# max      495.000000     46.000000

# %%
GCE.head()
# Out:
#    page_number    word  sent_count sentiment category
# 0          457    Fire          46      Fear  Emotion
# 1          306    Fire          44      Fear  Emotion
# 2          307    Fire          36      Fear  Emotion
# 3          399  County          30     Trust  Emotion
# 4          449    Fire          29      Fear  Emotion

# %%
print(GCE.groupby(['page_number'])['sentiment'].value_counts())
# Out:
# page_number  sentiment
# 2            Positive        15
#              Trust            7
#              Anticipation     6
#              Fear             4
#              Negative         4
#              Joy              2
#              Anger            1
#              Sadness          1
#              Surprise         1
# 3            Positive        11
#              Trust           11
#              Anticipation     6
#              Joy              5
#              Surprise         3
#              Negative         2
#              Sadness          2
#              Disgust          1
# 4            Anticipation     1
#              Negative         1
# 5            Trust            7
#              Positive         3
#              Anticipation     2
#              Fear             1
#              Joy              1
#              Negative         1
#              Surprise         1
# 7            Positive        10
#              Trust            8
# ...

# %%
GCE.sentiment = GCE.sentiment.replace({"Negative": "0","Positive": "1","Trust" :"2","Sadness":"0","Anticipation":"3","Surprise":"4","Fear":"5","Joy":"6","Anger":"7","Disgust":"8"})

# %%
GCE['sentiment'] = pd.to_numeric(GCE['sentiment'])
GCE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17338 entries, 0 to 17337
# Data columns (total 5 columns):
# page_number    17338 non-null int64
# word           17338 non-null object
# sent_count     17338 non-null int64
# sentiment      17338 non-null int64
# category       17338 non-null object
# dtypes: int64(3), object(2)
# memory usage: 677.3+ KB

# %%
GCE.hist()
#GCE.plot(x ='page_number', y='sentiment', kind = 'bar')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019EB4D460B8>,
# ...
#       dtype=object)

# %%
GCE.groupby('sentiment').hist()
# Out:
# sentiment
# 0    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# 1    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# 2    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# 3    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# 4    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# 5    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# 6    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# 7    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# 8    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
#GCE.groupby('page_number').sentiment.hist(alpha=1)

# %%
sns.distplot(GCE['sentiment'])

# %%
GCE.plot(x ='page_number', y='sentiment', kind = 'bar')

# %%
sns.jointplot(x="sentiment", y="page_number", data=GCE, kind="kde");

# %%
MCE = pd.read_csv(r"C:\Users\webfr\Desktop\DataScienceProject\MecklenburgCounty_emotion_data.csv")
MCE.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
MCE.sentiment = MCE.sentiment.replace({"Negative": "0","Positive": "1","Trust" :"2","Sadness":"0","Anticipation":"3","Surprise":"4","Fear":"5","Joy":"6","Anger":"7","Disgust":"8"})

# %%
sns.jointplot(x="sentiment", y="page_number", data=MCE, kind="kde");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-1ddb787aedd6> in <module>
# ----> 1 sns.jointplot(x="sentiment", y="page_number", data=MCE, kind="kde");
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2312         joint_kws.setdefault("shade", True)
#    2313         joint_kws.setdefault("cmap", cmap)
# -> 2314         grid.plot_joint(kdeplot, **joint_kws)
#    2315
#    2316         marginal_kws.setdefault("shade", True)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_joint(self, func, **kwargs)
#    1782         """
#    1783         plt.sca(self.ax_joint)
# -> 1784         func(self.x, self.y, **kwargs)
#    1785
#    1786         return self
#
# ...
