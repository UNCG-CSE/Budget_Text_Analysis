# %% [markdown]
# ### Data Pre-Processing
#
#
# 1. **Obtaining the data -** data consists of budget text documents in the form of PDF files obtained from the following organizations:
#
#    * [Guilford County](https://www.guilfordcountync.gov/home/showdocument?id=9497)
#    * [Durham County](https://www.dconc.gov/home/showdocument?id=27985)
#    * [City of Durham](https://durhamnc.gov/DocumentCenter/View/27412/FY20-Final-Budget)
#    * [City of Charlotte](https://charlottenc.gov/budget/FY2020%20Documents/FY%202020%20Adopted%20Budget%20Book%207-31%20Complete.pdf)
#    * [Mecklenburg County](https://www.mecknc.gov/CountyManagersOffice/OMB/Documents/FY2020%20Adopted%20Budget.pdf) <br/>
#    * [Wake County](http://www.wakegov.com/budget/fy20/Documents/FY20%20Adopted%20Budget%20Book.pdf)
#    * [City of Raleigh](https://user-2081353526.cld.bz/FY2020AdoptedBudget)
#
# After the PDF files are collected, they are compressed to reduce the size getting them ready to be converted into CSV files using an app developed by project mentor:
#            **[Jason Jones](https://www.linkedin.com/in/jones-jason-adam/),**
#            **click [here](https://jason-jones.shinyapps.io/Emotionizer/) for the App**
#
# 2. **Cleaning the data -** performing some popular text pre-processing techniques
#
#
# 3. **Organizing the data -** organizing the cleaned data into a way that is easy to input into other algorithms

# %% [markdown]
# ### FY2016 Data Preprocessig Starts Here

# %%
#Importing packages
import os
import glob
import nltk
import pandas as pd
import numpy as np

# %%
# change the current directory to read the data
os.chdir(r"C:\Users\Sultan\Documents\GitHub\Budget_Text_Analysis\util\data\FY2016\structured\original")

# %% [markdown]
# ### 1- Obtaining the data

# %% [markdown]
# #### Reading and labling data for all organizations

# %%
# 1- Reading Guilford-County data file 
GC_df = pd.read_csv("GuilfordCountyOriginalDataFY16.csv", engine='python')
# inserting "organization" column with static value 
# corresponding to the organization in question 
GC_df.insert(2, "organization", "Guilford County")


# 2- For Charlotte-City data
CC_df = pd.read_csv(r'CharlotteCityOriginalDataFY16.csv', engine='python')
CC_df.insert(2, "organization", "Charlotte City")

# 3- For Durham-City data
DCity_df = pd.read_csv(r'DurhamCityOriginalDataFY16.csv', engine='python')
DCity_df.insert(2, "organization", "Durham City")

# 4- For Durham-County data
DCounty_df = pd.read_csv(r'DurhamCountyOriginalDataFY16.csv', engine='python')
DCounty_df.insert(2, "organization", "Durham County")

# 5- For Mecklenburg-County data
MC_df = pd.read_csv(r'MecklenburgCountyOriginalDataFY16.csv', engine='python')
MC_df.insert(2, "organization", "Mecklenburg County")

# 6- For Raleigh-City data
RC_df = pd.read_csv(r'RaleighCityOriginalDataFY16.csv', engine='python')
RC_df.insert(2, "organization", "Raleigh City")

# 7- For Wake-County data
WC_df = pd.read_csv(r'WakeCountyOriginalDataFY16.csv', engine='python')
WC_df.insert(2, "organization", "Wake County")

# %%
# Combine all dataframes into a single dataframe using concat() function
# Row lables are adjusted automaticlly by passing ignore_index=True
data =  pd.concat([GC_df, CC_df, DCity_df, 
                   DCounty_df, MC_df, RC_df, WC_df], ignore_index=True)
data
# Out:
#         Unnamed: 0  page_number     organization     word
# 0                1            1  Guilford County       fy
# 1                2            1  Guilford County  adopted
# 2                3            1  Guilford County   budget
# 3                4            1  Guilford County     july
# 4                5            1  Guilford County     june
# ...            ...          ...              ...      ...
# 634953      148378          534      Wake County    index
# 634954      148379          534      Wake County   fiscal
# 634955      148380          534      Wake County     year
# 634956      148381          534      Wake County  adopted
# 634957      148382          534      Wake County   budget
#
# [634958 rows x 4 columns]

# %% [markdown]
# ### 2- Cleaning the Data

# %%
# listing columns in data frame 
list(data)
# Out:
# ['Unnamed: 0', 'page_number', 'organization', 'word']

# %% [markdown]
# #### Dropping and reordering columns

# %%
# delete columns using the columns parameter of drop
data = data.drop(columns="Unnamed: 0")

# re-order columns
data = data[['page_number','word','organization']]

data.head()
# Out:
#    page_number     word     organization
# 0            1       fy  Guilford County
# 1            1  adopted  Guilford County
# 2            1   budget  Guilford County
# 3            1     july  Guilford County
# 4            1     june  Guilford County

# %% [markdown]
# #### Adding "Year" column with a static value corresponding to the year in question

# %%
data.insert(3, "year", "FY2016")
data.head()
# Out:
#    page_number     word     organization    year
# 0            1       fy  Guilford County  FY2016
# 1            1  adopted  Guilford County  FY2016
# 2            1   budget  Guilford County  FY2016
# 3            1     july  Guilford County  FY2016
# 4            1     june  Guilford County  FY2016

# %% [markdown]
# ####  Text normalization:
#
# * ##### Lowercasing

# %%
# using a function to lowercase all text entries in column 'word'
data['word'] = data['word'].apply(lambda x: " ".join(x.lower() 
                                                     for x in x.split()))

data
# Out:
#         page_number     word     organization    year
# 0                 1       fy  Guilford County  FY2016
# 1                 1  adopted  Guilford County  FY2016
# 2                 1   budget  Guilford County  FY2016
# 3                 1     july  Guilford County  FY2016
# 4                 1     june  Guilford County  FY2016
# ...             ...      ...              ...     ...
# 634953          534    index      Wake County  FY2016
# 634954          534   fiscal      Wake County  FY2016
# 634955          534     year      Wake County  FY2016
# 634956          534  adopted      Wake County  FY2016
# 634957          534   budget      Wake County  FY2016
#
# [634958 rows x 4 columns]

# %% [markdown]
# * ##### Lemmatization

# %% [markdown]
# #### Removing stop words

# %%
# Load library
from nltk.corpus import stopwords

# Download the set of stop words the first time
nltk.download('stopwords')

# Load stop words
stop_words = stopwords.words('english')

data['word'] = data['word'].apply(lambda x: " ".join(x 
                            for x in x.split() if x not in stop_words))
data.head(50)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sultan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#     page_number           word     organization    year
# 0             1             fy  Guilford County  FY2016
# 1             1        adopted  Guilford County  FY2016
# 2             1         budget  Guilford County  FY2016
# 3             1           july  Guilford County  FY2016
# 4             1           june  Guilford County  FY2016
# 5             3         fiscal  Guilford County  FY2016
# 6             3           year  Guilford County  FY2016
# 7             3        adopted  Guilford County  FY2016
# 8             3         budget  Guilford County  FY2016
# 9             3       guilford  Guilford County  FY2016
# 10            3         county  Guilford County  FY2016
# 11            3          board  Guilford County  FY2016
# 12            3                 Guilford County  FY2016
# 13            3  commissioners  Guilford County  FY2016
# 14            3           hank  Guilford County  FY2016
# 15            3        henning  Guilford County  FY2016
# 16            3          board  Guilford County  FY2016
# 17            3          chair  Guilford County  FY2016
# 18            3           jeff  Guilford County  FY2016
# 19            3       phillips  Guilford County  FY2016
# 20            3           vice  Guilford County  FY2016
# 21            3          chair  Guilford County  FY2016
# 22            3           alan  Guilford County  FY2016
# 23            3        branson  Guilford County  FY2016
# 24            3           alan  Guilford County  FY2016
# 25            3         perdue  Guilford County  FY2016
# 26            3        carolyn  Guilford County  FY2016
# 27            3        coleman  Guilford County  FY2016
# 28            3              j  Guilford County  FY2016
# 29            3       carlvena  Guilford County  FY2016
# 30            3         foster  Guilford County  FY2016
# 31            3         justin  Guilford County  FY2016
# 32            3         conrad  Guilford County  FY2016
# 33            3            kay  Guilford County  FY2016
# 34            3        cashion  Guilford County  FY2016
# 35            3            ray  Guilford County  FY2016
# 36            3          trapp  Guilford County  FY2016
# 37            3         office  Guilford County  FY2016
# 38            3                 Guilford County  FY2016
# 39            3         budget  Guilford County  FY2016
# 40            3     management  Guilford County  FY2016
# 41            3                 Guilford County  FY2016
# 42            3     evaluation  Guilford County  FY2016
# 43            3         county  Guilford County  FY2016
# 44            3        manager  Guilford County  FY2016
# 45            3        michael  Guilford County  FY2016
# 46            3        halford  Guilford County  FY2016
# 47            3         budget  Guilford County  FY2016
# 48            3       director  Guilford County  FY2016
# 49            3          marty  Guilford County  FY2016

# %%
# Regex with the pattern replacing not alphanumeric/whitespace with a space
data['word'] = data['word'].str.replace('[^\w\s]','')

data.head()
# Out:
#    page_number     word     organization    year
# 0            1       fy  Guilford County  FY2016
# 1            1  adopted  Guilford County  FY2016
# 2            1   budget  Guilford County  FY2016
# 3            1     july  Guilford County  FY2016
# 4            1     june  Guilford County  FY2016

# %%
# Replacing empty cells with null values, so we can drop all NaN values later
data['word'].replace('', np.nan, inplace=True)

# Drop all NaN values from the data frames
data.dropna(subset=['word'], inplace=True)
data.head()
# Out:
#    page_number     word     organization    year
# 0            1       fy  Guilford County  FY2016
# 1            1  adopted  Guilford County  FY2016
# 2            1   budget  Guilford County  FY2016
# 3            1     july  Guilford County  FY2016
# 4            1     june  Guilford County  FY2016

# %% [markdown]
# ### 2- Organizing the Data

# %% [markdown]
# We already created a corpus in an earlier step. The definition of a corpus is a collection of texts, and they are all put together neatly in a pandas dataframe here.

# %%
# Let's take a look at our dataframe
data
# Out:
#         page_number     word     organization    year
# 0                 1       fy  Guilford County  FY2016
# 1                 1  adopted  Guilford County  FY2016
# 2                 1   budget  Guilford County  FY2016
# 3                 1     july  Guilford County  FY2016
# 4                 1     june  Guilford County  FY2016
# ...             ...      ...              ...     ...
# 634953          534    index      Wake County  FY2016
# 634954          534   fiscal      Wake County  FY2016
# 634955          534     year      Wake County  FY2016
# 634956          534  adopted      Wake County  FY2016
# 634957          534   budget      Wake County  FY2016
#
# [454002 rows x 4 columns]

# %% [markdown]
# #### Dataframe to one single and clean csv file

# %%
# Export dataframe to csv
data.to_csv(r"C:\Users\Sultan\Documents\GitHub\Budget_Text_Analysis\util\data\PreprocessedOriginalData\PreprocessedOriginalDataFY16.csv", index=False, encoding='utf-8-sig')

# %%
# Change the dirctory for pickle file to be stored properly
os.chdir(r"C:\Users\Sultan\Documents\GitHub\Budget_Text_Analysis\util\data\PreprocessedOriginalData\pickle") 
# Let's pickle it for later use
data.to_pickle("DataFY16.pkl")
