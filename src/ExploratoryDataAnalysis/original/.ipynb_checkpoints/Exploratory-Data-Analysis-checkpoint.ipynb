# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Most Common Words

# %%
import os

# %%
# Change the dirctory for pickle file to be read
os.chdir(r"C:\Users\Sultan\Documents\GitHub\Budget_Text_Analysis\util\data\PreprocessedOriginalData\pickle") 

# Read in the document-term matrix
import pandas as pd

data = pd.read_pickle('DataFY20.pkl')
data = data.transpose()
data.head()
# Out:
#                        0                1                2       \
# page_number                 2                2                2
# word                 guilford           county
# organization  Guilford County  Guilford County  Guilford County
# year                   FY2020           FY2020           FY2020
#
#                        3                4                5       \
# page_number                 2                2                2
# word                                   numbers
# organization  Guilford County  Guilford County  Guilford County
# year                   FY2020           FY2020           FY2020
#
#                        6                7                8       \
# page_number                 2                2                2
# word                    makes               us            count
# organization  Guilford County  Guilford County  Guilford County
# year                   FY2020           FY2020           FY2020
#
#                        9       ...       638121       638122       638123  \
# page_number                 2  ...          498          498          498
# word                   county  ...         wake       county   government
# organization  Guilford County  ...  Wake County  Wake County  Wake County
# year                   FY2020  ...       FY2020       FY2020       FY2020
#
#                       638124       638125       638126       638127  \
# page_number              498          498          498          498
# word          organizational        chart        index       fiscal
# organization     Wake County  Wake County  Wake County  Wake County
# year                  FY2020       FY2020       FY2020       FY2020
#
#                    638128       638129       638130
# page_number           498          498          498
# word                 year      adopted       budget
# organization  Wake County  Wake County  Wake County
# year               FY2020       FY2020       FY2020
#
# [4 rows x 638131 columns]
